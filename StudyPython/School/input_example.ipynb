# %%
a,b,c,d = eval(input())
# input: 1,2,3,4
print(a,b,c,d)

# %%
lst = input().split()
# input: 1 2 3 4
print(lst)

# %%
lst = list(map(int, input().split()))
# input: 1 2 3 4 5
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst = [int(x) for x in input().split()]
# input: 1 2 3 4 5
print(lst)
# Out:
# [1, 2, 3, 4, 5]
